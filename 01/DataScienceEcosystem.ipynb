# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# * Understand the basics of Markdown and how to format text in Jupyter Notebooks.
# * Learn and apply arithmetic expressions in Python.
# * Convert time units from minutes to hours.
# * List popular languages for Data Science.
# * Explore and utilize open-source tools in the data science environment.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. C++

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. NumPy
# 2. Pandas
# 3. Polars
# 4. Scikit Learn
#  Matplotlib

# %% [markdown]
# | Data Science Tools |
# | :----------------- |
# | Jupyter Notebook   |
# | RStudio            |
# | Apache Zeppelin    |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.
# * Addition: `result_add = 2 + 3  # 5`
# * Subtraction: `result_sub = 5 - 2  # 3`
# * Multiplication: `result_mul = 4 * 3  # 12`
# * Division: `result_div = 10 / 2  # 5`
# * Exponentiation: `result_exp = 2 ** 3  # 8`
# * Modulus: `result_mod = 10 % 3  # 1`

# %%
# This is a simple arithmetic expression to multiply then add integers
result = (3 * 4) + 5
print(result)
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
hours = 200 / 60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Rafael Carlos Roldán Guerra
